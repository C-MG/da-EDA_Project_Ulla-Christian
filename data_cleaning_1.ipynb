# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Floats (decimal numbers) should be displayed rounded with 2 decimal places
pd.options.display.float_format = "{:,.2f}".format
# Set style for plots
plt.style.use('fivethirtyeight')

# %%
# read in csv file and display first 5 rows of datset
df = pd.read_csv("data/Orders.csv")
df.head()
# Out:
#    Index        Order ID  Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755   16/1/2019    Second Class    EH-13945
# 1     45  CA-2019-118255   11/3/2019     First Class    ON-18715
# 2     48  CA-2019-169194   20/6/2019  Standard Class    LH-16900
# 3     60  CA-2019-111682   17/6/2019     First Class    TB-21055
# 4     63  CA-2018-135545  24/11/2018  Standard Class    KM-16720
#
#      Customer Name Origin Channel Country/Region         City       State  \
# 0    Eric Hoffmann          Email  United States  Los Angeles  California
# 1    Odella Nelson          Sales  United States        Eagan   Minnesota
# 2   Lena Hernandez          Email  United States        Dover    Delaware
# 3  Ted Butterfield          Email  United States         Troy    New York
# 4     Kunst Miller          Email  United States  Los Angeles  California
#
#    Postal Code   Region                 Category Sub-Category  \
# 0    90,049.00     West  Special Projects Muesil  Gluten Free
# 1    55,122.00  Central  Special Projects Muesil  Gluten Free
# 2    19,901.00     East  Special Projects Muesil  Gluten Free
# 3    12,180.00     East  Special Projects Muesil  Gluten Free
# 4    90,004.00     West  Special Projects Muesil  Gluten Free
#
#         Product ID  Sales  Quantity  Discount  Profit
# 0  TEC-AC-10003027  90.57         3      0.00   11.77
# 1  TEC-AC-10000171  45.98         2      0.00   19.77
# 2  TEC-AC-10002167  45.00         3      0.00    4.95
# 3  TEC-AC-10002167  30.00         2      0.00    3.30
# 4  TEC-AC-10004633  13.98         2      0.00    6.15

# %%
df.columns
# Out:
# Index(['Index', 'Order ID', 'Order Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Origin Channel', 'Country/Region', 'City', 'State',
#        'Postal Code', 'Region', 'Category', 'Sub-Category', 'Product ID',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Mode       9994 non-null   object
#  4   Customer ID     9994 non-null   object
#  5   Customer Name   9994 non-null   object
#  6   Origin Channel  9994 non-null   object
#  7   Country/Region  9994 non-null   object
#  8   City            9994 non-null   object
#  9   State           9994 non-null   object
#  10  Postal Code     9983 non-null   float64
#  11  Region          9994 non-null   object
#  12  Category        9994 non-null   object
#  13  Sub-Category    9994 non-null   object
#  14  Product ID      9994 non-null   object
#  15  Sales           9994 non-null   float64
#  16  Quantity        9994 non-null   int64
#  17  Discount        9994 non-null   float64
#  18  Profit          9994 non-null   float64
# dtypes: float64(4), int64(2), object(13)
# memory usage: 1.4+ MB

# %%
df.drop(["Country/Region"], axis=1, inplace=True)
df.head()
# Out:
#    Index        Order ID  Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755   16/1/2019    Second Class    EH-13945
# 1     45  CA-2019-118255   11/3/2019     First Class    ON-18715
# 2     48  CA-2019-169194   20/6/2019  Standard Class    LH-16900
# 3     60  CA-2019-111682   17/6/2019     First Class    TB-21055
# 4     63  CA-2018-135545  24/11/2018  Standard Class    KM-16720
#
#      Customer Name Origin Channel         City       State  Postal Code  \
# 0    Eric Hoffmann          Email  Los Angeles  California    90,049.00
# 1    Odella Nelson          Sales        Eagan   Minnesota    55,122.00
# 2   Lena Hernandez          Email        Dover    Delaware    19,901.00
# 3  Ted Butterfield          Email         Troy    New York    12,180.00
# 4     Kunst Miller          Email  Los Angeles  California    90,004.00
#
#     Region                 Category Sub-Category       Product ID  Sales  \
# 0     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
# 2     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  45.00
# 3     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  30.00
# 4     West  Special Projects Muesil  Gluten Free  TEC-AC-10004633  13.98
#
#    Quantity  Discount  Profit
# 0         3      0.00   11.77
# 1         2      0.00   19.77
# 2         3      0.00    4.95
# 3         2      0.00    3.30
# 4         2      0.00    6.15

# %% [markdown]
# Check for duplicates in original data (sheets file): there are no data to signify an individual dataset (row) as order_ids and product_ids are assigned several times, e.g. order of two different products by same customer gets same order_id.

# %%
df["Order Date"]= df["Order Date"].str.replace("/", ".")
df.head()
# Out:
#    Index        Order ID  Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755   16.1.2019    Second Class    EH-13945
# 1     45  CA-2019-118255   11.3.2019     First Class    ON-18715
# 2     48  CA-2019-169194   20.6.2019  Standard Class    LH-16900
# 3     60  CA-2019-111682   17.6.2019     First Class    TB-21055
# 4     63  CA-2018-135545  24.11.2018  Standard Class    KM-16720
#
#      Customer Name Origin Channel         City       State  Postal Code  \
# 0    Eric Hoffmann          Email  Los Angeles  California    90,049.00
# 1    Odella Nelson          Sales        Eagan   Minnesota    55,122.00
# 2   Lena Hernandez          Email        Dover    Delaware    19,901.00
# 3  Ted Butterfield          Email         Troy    New York    12,180.00
# 4     Kunst Miller          Email  Los Angeles  California    90,004.00
#
#     Region                 Category Sub-Category       Product ID  Sales  \
# 0     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
# 2     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  45.00
# 3     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  30.00
# 4     West  Special Projects Muesil  Gluten Free  TEC-AC-10004633  13.98
#
#    Quantity  Discount  Profit
# 0         3      0.00   11.77
# 1         2      0.00   19.77
# 2         3      0.00    4.95
# 3         2      0.00    3.30
# 4         2      0.00    6.15

# %%
df["Order Date"]=pd.to_datetime(df["Order Date"], format='%d.%m.%Y')

df["Order Date"]=pd.to_datetime(df["Order Date"].dt.date)
df.head()
# Out:
#    Index        Order ID Order Date       Ship Mode Customer ID  \
# 0     27  CA-2019-121755 2019-01-16    Second Class    EH-13945
# 1     45  CA-2019-118255 2019-03-11     First Class    ON-18715
# 2     48  CA-2019-169194 2019-06-20  Standard Class    LH-16900
# 3     60  CA-2019-111682 2019-06-17     First Class    TB-21055
# 4     63  CA-2018-135545 2018-11-24  Standard Class    KM-16720
#
#      Customer Name Origin Channel         City       State  Postal Code  \
# 0    Eric Hoffmann          Email  Los Angeles  California    90,049.00
# 1    Odella Nelson          Sales        Eagan   Minnesota    55,122.00
# 2   Lena Hernandez          Email        Dover    Delaware    19,901.00
# 3  Ted Butterfield          Email         Troy    New York    12,180.00
# 4     Kunst Miller          Email  Los Angeles  California    90,004.00
#
#     Region                 Category Sub-Category       Product ID  Sales  \
# 0     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
# 2     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  45.00
# 3     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  30.00
# 4     West  Special Projects Muesil  Gluten Free  TEC-AC-10004633  13.98
#
#    Quantity  Discount  Profit
# 0         3      0.00   11.77
# 1         2      0.00   19.77
# 2         3      0.00    4.95
# 3         2      0.00    3.30
# 4         2      0.00    6.15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 18 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   datetime64[ns]
#  3   Ship Mode       9994 non-null   object
#  4   Customer ID     9994 non-null   object
#  5   Customer Name   9994 non-null   object
#  6   Origin Channel  9994 non-null   object
#  7   City            9994 non-null   object
#  8   State           9994 non-null   object
#  9   Postal Code     9983 non-null   float64
#  10  Region          9994 non-null   object
#  11  Category        9994 non-null   object
#  12  Sub-Category    9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Sales           9994 non-null   float64
#  15  Quantity        9994 non-null   int64
#  16  Discount        9994 non-null   float64
#  17  Profit          9994 non-null   float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(11)
# memory usage: 1.4+ MB

# %%
# export Dataframe into csv File on my Computer
df.to_csv('/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/orders_cleaned.csv')

# %%
# make copy of df and name as df_orders for better distinguishabliity
#df_orders=pd.DataFrame(df)

# %%
df_opd = pd.read_csv("data/OrderProcessData.csv")
df_opd.head()
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode
# 0    3074  CA-2019-125206   3/1/2019         07/01/2019              Express
# 1    4919  CA-2019-160304   2/1/2019         09/01/2019  Standard Processing
# 2    4920  CA-2019-160304   2/1/2019         09/01/2019  Standard Processing
# 3    8604  US-2019-116365   3/1/2019         09/01/2019  Standard Processing
# 4    8605  US-2019-116365   3/1/2019         09/01/2019  Standard Processing

# %%
df_opd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Row ID              5899 non-null   int64
#  1   Order ID            5899 non-null   object
#  2   Order Date          5899 non-null   object
#  3   On Truck Scan Date  5899 non-null   object
#  4   Ship Mode           5899 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 230.6+ KB

# %%
# check for duplicates
df_opd["Row ID"].duplicated().value_counts()# convert trending_date and publish_time into datetime and extract date part from publish_time
# format specifies the present form of our argument we pass into the function
#df['trending_date'] = pd.to_datetime(df['trending_date'], format='%y.%d.%m')
#df['publish_time'] = pd.to_datetime(df['publish_time'], format='%Y-%m-%dT%H:%M:%S.%fZ')
#df['publish_date'] = pd.to_datetime(df['publish_time'].dt.date)
# Out:
# False    5899
# Name: Row ID, dtype: int64

# %%
df_opd["Order Date"]= df["Order Date"].str.replace("/", ".")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb Cell 17' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000015?line=0'>1</a> df_opd["Order Date"]= df["Order Date"].str.replace("/", ".")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5567'>5568</a> if (
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5568'>5569</a>     name not in self._internal_names_set
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5569'>5570</a>     and name not in self._metadata
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5570'>5571</a>     and name not in self._accessors
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5571'>5572</a>     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5572'>5573</a> ):
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5573'>5574</a>     return self[name]
# -> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/generic.py?line=5574'>5575</a> return object.__getattribute__(self, name)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=178'>179</a> if obj is None:
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=179'>180</a>     # we're accessing the attribute of the class, i.e., Dataset.geo
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=180'>181</a>     return self._accessor
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=181'>182</a> accessor_obj = self._accessor(obj)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=182'>183</a> # Replace the property with the accessor object. Inspired by:
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=183'>184</a> # https://www.pydanny.com/cached-property.html
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=184'>185</a> # We need to use object.__setattr__ because we overwrite __setattr__ on
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=185'>186</a> # NDFrame
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/accessor.py?line=186'>187</a> object.__setattr__(obj, self._name, accessor_obj)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py:177, in StringMethods.__init__(self, data)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=173'>174</a> def __init__(self, data):
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=174'>175</a>     from pandas.core.arrays.string_ import StringDtype
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=176'>177</a>     self._inferred_dtype = self._validate(data)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=177'>178</a>     self._is_categorical = is_categorical_dtype(data.dtype)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=178'>179</a>     self._is_string = isinstance(data.dtype, StringDtype)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py:231, in StringMethods._validate(data)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=227'>228</a> inferred_dtype = lib.infer_dtype(values, skipna=True)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=229'>230</a> if inferred_dtype not in allowed_types:
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=230'>231</a>     raise AttributeError("Can only use .str accessor with string values!")
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/strings/accessor.py?line=231'>232</a> return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
# date time for Order Date
df_opd["Order Date"]=pd.to_datetime(df_opd["Order Date"], format='%d.%m.%Y')
df_opd["Order Date"]=pd.to_datetime(df_opd["Order Date"].dt.date)
df_opd.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=508'>509</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=509'>510</a>     values, tz = conversion.datetime_to_datetime64(arg)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=510'>511</a>     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb Cell 18' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000016?line=0'>1</a> # date time for Order Date
# ----> <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000016?line=1'>2</a> df_opd["Order Date"]=pd.to_datetime(df_opd["Order Date"], format='%d.%m.%Y')
#       <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000016?line=2'>3</a> df_opd["Order Date"]=pd.to_datetime(df_opd["Order Date"].dt.date)
#       <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000016?line=3'>4</a> df_opd.head()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=1044'>1045</a>             result = arg.tz_localize(tz)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=1045'>1046</a> elif isinstance(arg, ABCSeries):
# -> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=1046'>1047</a>     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=1047'>1048</a>     if not cache_array.empty:
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=1048'>1049</a>         result = arg.map(cache_array)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=194'>195</a> unique_dates = unique(arg)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=195'>196</a> if len(unique_dates) < len(arg):
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=196'>197</a>     cache_dates = convert_listlike(unique_dates, format)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=197'>198</a>     cache_array = Series(cache_dates, index=unique_dates)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=198'>199</a>     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:394, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=390'>391</a>         format = None
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=392'>393</a> if format is not None:
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=393'>394</a>     res = _to_datetime_with_format(
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=394'>395</a>         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=395'>396</a>     )
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=396'>397</a>     if res is not None:
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=397'>398</a>         return res
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:514, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=511'>512</a>     return DatetimeIndex._simple_new(dta, name=name)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=512'>513</a> except (ValueError, TypeError):
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=513'>514</a>     raise err
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:501, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=497'>498</a>             return _box_as_indexlike(result, utc=utc, name=name)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=499'>500</a>     # fallback
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=500'>501</a>     res = _array_strptime_with_fallback(
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=501'>502</a>         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=502'>503</a>     )
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=503'>504</a>     return res
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=505'>506</a> except ValueError as err:
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=506'>507</a>     # Fallback to try to convert datetime objects if timezone-aware
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=507'>508</a>     #  datetime objects are found without passing `utc=True`
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:437, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=433'>434</a> utc = tz == "utc"
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=435'>436</a> try:
# --> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=436'>437</a>     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=437'>438</a>     if "%Z" in fmt or "%z" in fmt:
#     <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/tools/datetimes.py?line=438'>439</a>         return _return_parsed_timezone_results(result, timezones, tz, name)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '3/1/2019' does not match format '%d.%m.%Y' (match)

# %%
# date time for On Truck Scan 
df_opd["On Truck Scan Date"]= df_opd["On Truck Scan Date"].str.replace("/", ".")
df_opd["On Truck Scan Date"]=pd.to_datetime(df_opd["On Truck Scan Date"], format='%d.%m.%Y')
df_opd["On Truck Scan Date"]=pd.to_datetime(df_opd["On Truck Scan Date"].dt.date)
df_opd.head()
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode
# 0    3074  CA-2019-125206   3/1/2019         2019-01-07              Express
# 1    4919  CA-2019-160304   2/1/2019         2019-01-09  Standard Processing
# 2    4920  CA-2019-160304   2/1/2019         2019-01-09  Standard Processing
# 3    8604  US-2019-116365   3/1/2019         2019-01-09  Standard Processing
# 4    8605  US-2019-116365   3/1/2019         2019-01-09  Standard Processing

# %%
# date time for On Truck Scan 
df_opd["Order Date"]= df_opd["Order Date"].str.replace("/", ".")
df_opd["Order Date"]=pd.to_datetime(df_opd["Order Date"], format='%d.%m.%Y')
df_opd["Order Date"]=pd.to_datetime(df_opd["Order Date"].dt.date)
df_opd.head()
# Out:
#    Row ID        Order ID Order Date On Truck Scan Date            Ship Mode
# 0    3074  CA-2019-125206 2019-01-03         2019-01-07              Express
# 1    4919  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 2    4920  CA-2019-160304 2019-01-02         2019-01-09  Standard Processing
# 3    8604  US-2019-116365 2019-01-03         2019-01-09  Standard Processing
# 4    8605  US-2019-116365 2019-01-03         2019-01-09  Standard Processing

# %%
# read Intern Data Study
df_ids = pd.read_csv("data/InternDataStudy.csv")
df_ids.head()
# Out:
#          Order ID Ready to Ship Date Pickup Date
# 0  CA-2019-116540         02/09/2019  03/09/2019
# 1  CA-2019-116540         02/09/2019  03/09/2019
# 2  CA-2019-129847         04/09/2019  04/09/2019
# 3  CA-2019-129630         04/09/2019  04/09/2019
# 4  CA-2019-106278         05/09/2019  06/09/2019

# %%
df_ids.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Order ID            290 non-null    object
#  1   Ready to Ship Date  290 non-null    object
#  2   Pickup Date         290 non-null    object
# dtypes: object(3)
# memory usage: 6.9+ KB

# %%
# check for duplicates
df_ids["Order ID"].duplicated().value_counts()
# Out:
# False    204
# True      86
# Name: Order ID, dtype: int64

# %% [markdown]
# Check if the same order ID is always on the same truck or not. If not, then no duplicate!

# %%
# Datetime for Ready to Ship Date
df_ids["Ready to Ship Date"]= df_ids["Ready to Ship Date"].str.replace("/", ".")
df_ids["Ready to Ship Date"]=pd.to_datetime(df_ids["Ready to Ship Date"], format='%d.%m.%Y')
df_ids["Ready to Ship Date"]=pd.to_datetime(df_ids["Ready to Ship Date"].dt.date)
df_ids.head()
# Out:
#          Order ID Ready to Ship Date Pickup Date
# 0  CA-2019-116540         2019-09-02  03/09/2019
# 1  CA-2019-116540         2019-09-02  03/09/2019
# 2  CA-2019-129847         2019-09-04  04/09/2019
# 3  CA-2019-129630         2019-09-04  04/09/2019
# 4  CA-2019-106278         2019-09-05  06/09/2019

# %%
# Datetime for Pickup Date
df_ids["Pickup Date"]= df_ids["Pickup Date"].str.replace("/", ".")
df_ids["Pickup Date"]=pd.to_datetime(df_ids["Pickup Date"], format='%d.%m.%Y')
df_ids["Pickup Date"]=pd.to_datetime(df_ids["Pickup Date"].dt.date)
df_ids.head()
# Out:
#          Order ID Ready to Ship Date Pickup Date
# 0  CA-2019-116540         2019-09-02  2019-09-03
# 1  CA-2019-116540         2019-09-02  2019-09-03
# 2  CA-2019-129847         2019-09-04  2019-09-04
# 3  CA-2019-129630         2019-09-04  2019-09-04
# 4  CA-2019-106278         2019-09-05  2019-09-06

# %%
# read Campaign Data
df_cd = pd.read_csv("data/Campaign Data.csv")
df_cd.head()
# Out:
#          Order ID Arrival Scan Date     Customer Name
# 0  CA-2019-109666        03/05/2019      Kunst Miller
# 1  CA-2019-138933        03/05/2019       Jack Lebron
# 2  CA-2019-130001        03/05/2019  Heather Kirkland
# 3  CA-2019-113061        06/05/2019         Ed Ludwig
# 4  CA-2019-162138        06/05/2019       Grace Kelly

# %%
df_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           333 non-null    object
#  1   Arrival Scan Date  333 non-null    object
#  2   Customer Name      333 non-null    object
# dtypes: object(3)
# memory usage: 7.9+ KB

# %%
# Datetime for Arrival Scan Date
df_cd["Arrival Scan Date"]= df_cd["Arrival Scan Date"].str.replace("/", ".")
df_cd["Arrival Scan Date"]=pd.to_datetime(df_cd["Arrival Scan Date"], format='%d.%m.%Y')
df_cd["Arrival Scan Date"]=pd.to_datetime(df_cd["Arrival Scan Date"].dt.date)
df_cd.head()
# Out:
#          Order ID Arrival Scan Date     Customer Name
# 0  CA-2019-109666        2019-05-03      Kunst Miller
# 1  CA-2019-138933        2019-05-03       Jack Lebron
# 2  CA-2019-130001        2019-05-03  Heather Kirkland
# 3  CA-2019-113061        2019-05-06         Ed Ludwig
# 4  CA-2019-162138        2019-05-06       Grace Kelly

# %%
# import Dataframe from csv File on my Computer
df_hypo = pd.read_csv("/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/orders_cleaned.csv")

# %%
df_hypo.head()
# Out:
#    Unnamed: 0  Index        Order ID  Order Date       Ship Mode Customer ID  \
# 0           0     27  CA-2019-121755  2019-01-16    Second Class    EH-13945
# 1           1     45  CA-2019-118255  2019-03-11     First Class    ON-18715
# 2           2     48  CA-2019-169194  2019-06-20  Standard Class    LH-16900
# 3           3     60  CA-2019-111682  2019-06-17     First Class    TB-21055
# 4           4     63  CA-2018-135545  2018-11-24  Standard Class    KM-16720
#
#      Customer Name Origin Channel         City       State  Postal Code  \
# 0    Eric Hoffmann          Email  Los Angeles  California    90,049.00
# 1    Odella Nelson          Sales        Eagan   Minnesota    55,122.00
# 2   Lena Hernandez          Email        Dover    Delaware    19,901.00
# 3  Ted Butterfield          Email         Troy    New York    12,180.00
# 4     Kunst Miller          Email  Los Angeles  California    90,004.00
#
#     Region                 Category Sub-Category       Product ID  Sales  \
# 0     West  Special Projects Muesil  Gluten Free  TEC-AC-10003027  90.57
# 1  Central  Special Projects Muesil  Gluten Free  TEC-AC-10000171  45.98
# 2     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  45.00
# 3     East  Special Projects Muesil  Gluten Free  TEC-AC-10002167  30.00
# 4     West  Special Projects Muesil  Gluten Free  TEC-AC-10004633  13.98
#
#    Quantity  Discount  Profit
# 0         3      0.00   11.77
# 1         2      0.00   19.77
# 2         3      0.00    4.95
# 3         2      0.00    3.30
# 4         2      0.00    6.15

# %%
inner_join = pd.merge(df_hypo, 
                      df_opd, 
                      on ='Order ID', 
                      how ='inner')
inner_join
# Out:
#        Unnamed: 0  Index        Order ID Order Date_x     Ship Mode_x  \
# 0               0     27  CA-2019-121755   2019-01-16    Second Class
# 1               0     27  CA-2019-121755   2019-01-16    Second Class
# 2            5558     26  CA-2019-121755   2019-01-16    Second Class
# 3            5558     26  CA-2019-121755   2019-01-16    Second Class
# 4               1     45  CA-2019-118255   2019-03-11     First Class
# ...           ...    ...             ...          ...             ...
# 17520        9963   9463  US-2020-109610   2020-11-25    Second Class
# 17521        9979   9760  CA-2019-146913   2019-10-31  Standard Class
# 17522        9984   9808  CA-2020-107209   2020-07-27    Second Class
# 17523        9986   9830  US-2020-152842   2020-07-16  Standard Class
# 17524        9988   9880  CA-2019-122581   2019-08-21  Standard Class
#
#       Customer ID     Customer Name Origin Channel           City  \
# 0        EH-13945     Eric Hoffmann          Email    Los Angeles
# 1        EH-13945     Eric Hoffmann          Email    Los Angeles
# 2        EH-13945     Eric Hoffmann          Email    Los Angeles
# 3        EH-13945     Eric Hoffmann          Email    Los Angeles
# 4        ON-18715     Odella Nelson          Sales          Eagan
# ...           ...               ...            ...            ...
# 17520    BS-11590     Brendan Sweed          Sales     Louisville
# 17521    SF-20965   Sylvia Foulston          Sales  San Francisco
# 17522    JW-15955    Joni Wasserman          Email        Raleigh
# 17523    NF-18385  Natalie Fritzler          Email      Charlotte
# 17524    JK-15370        Jay Kimmel          Email  New York City
#
#                 State  ...       Sub-Category       Product ID    Sales  \
# 0          California  ...        Gluten Free  TEC-AC-10003027    90.57
# 1          California  ...        Gluten Free  TEC-AC-10003027    90.57
# 2          California  ...  Super Fibre Boost  OFF-BI-10001634    11.65
# 3          California  ...  Super Fibre Boost  OFF-BI-10001634    11.65
# 4           Minnesota  ...        Gluten Free  TEC-AC-10000171    45.98
# ...               ...  ...                ...              ...      ...
# 17520        Kentucky  ...          With Nuts  FUR-CH-10001854   701.96
# 17521      California  ...          With Nuts  FUR-CH-10001854 1,403.92
# 17522  North Carolina  ...          With Nuts  FUR-CH-10001146   194.85
# 17523  North Carolina  ...          With Nuts  FUR-CH-10004218   242.35
# 17524        New York  ...          With Nuts  FUR-CH-10002961   573.17
#
#       Quantity Discount  Profit  Row ID  Order Date_y  On Truck Scan Date  \
# 0            3     0.00   11.77      26    2019-01-16          2019-01-23
# 1            3     0.00   11.77      27    2019-01-16          2019-01-23
# 2            2     0.20    4.22      26    2019-01-16          2019-01-23
# 3            2     0.20    4.22      27    2019-01-16          2019-01-23
# 4            2     0.00   19.77      45    2019-03-11          2019-03-13
# ...        ...      ...     ...     ...           ...                 ...
# 17520        2     0.00  168.47    9463    2020-11-25          2020-12-02
# 17521        5     0.20   70.20    9760    2019-10-31          2019-11-06
# 17522        4     0.20   12.18    9808    2020-07-27          2020-08-05
# 17523        3     0.20   15.15    9830    2020-07-16          2020-07-24
# 17524        7     0.10   63.69    9880    2019-08-21          2019-08-28
#
#                Ship Mode_y
# 0      Standard Processing
# 1      Standard Processing
# 2      Standard Processing
# 3      Standard Processing
# 4                  Express
# ...                    ...
# 17520  Standard Processing
# 17521  Standard Processing
# 17522  Standard Processing
# 17523  Standard Processing
# 17524  Standard Processing
#
# [17525 rows x 23 columns]

# %%
# check if second class and standard class were unified in one class standard processing and first class renamed in Express in df_opd
inner_join[['Index', 'Order ID', 'Order Date_x', 'Order Date_y', 'Ship Mode_x','Ship Mode_y']]
# Out:
#        Index        Order ID Order Date_x Order Date_y     Ship Mode_x  \
# 0         27  CA-2019-121755   2019-01-16   2019-01-16    Second Class
# 1         27  CA-2019-121755   2019-01-16   2019-01-16    Second Class
# 2         26  CA-2019-121755   2019-01-16   2019-01-16    Second Class
# 3         26  CA-2019-121755   2019-01-16   2019-01-16    Second Class
# 4         45  CA-2019-118255   2019-03-11   2019-03-11     First Class
# ...      ...             ...          ...          ...             ...
# 17520   9463  US-2020-109610   2020-11-25   2020-11-25    Second Class
# 17521   9760  CA-2019-146913   2019-10-31   2019-10-31  Standard Class
# 17522   9808  CA-2020-107209   2020-07-27   2020-07-27    Second Class
# 17523   9830  US-2020-152842   2020-07-16   2020-07-16  Standard Class
# 17524   9880  CA-2019-122581   2019-08-21   2019-08-21  Standard Class
#
#                Ship Mode_y
# 0      Standard Processing
# 1      Standard Processing
# 2      Standard Processing
# 3      Standard Processing
# 4                  Express
# ...                    ...
# 17520  Standard Processing
# 17521  Standard Processing
# 17522  Standard Processing
# 17523  Standard Processing
# 17524  Standard Processing
#
# [17525 rows x 6 columns]

# %%
# rename ship modes in df_hypo

df_hypo.loc[df_hypo['Ship Mode'] == 'Standard Class', 'Ship Mode'] = "Standard Processing"
df_hypo.loc[df_hypo['Ship Mode'] == 'Second Class', 'Ship Mode'] = "Standard Processing"
df_hypo.loc[df_hypo['Ship Mode'] == 'First Class', 'Ship Mode'] = "Express"
df_hypo['Unnamed: 0'].drop
df_hypo.head()
# Out:
#    Unnamed: 0  Index        Order ID  Order Date            Ship Mode  \
# 0           0     27  CA-2019-121755  2019-01-16  Standard Processing
# 1           1     45  CA-2019-118255  2019-03-11              Express
# 2           2     48  CA-2019-169194  2019-06-20  Standard Processing
# 3           3     60  CA-2019-111682  2019-06-17              Express
# 4           4     63  CA-2018-135545  2018-11-24  Standard Processing
#
#   Customer ID    Customer Name Origin Channel         City       State  \
# 0    EH-13945    Eric Hoffmann          Email  Los Angeles  California
# 1    ON-18715    Odella Nelson          Sales        Eagan   Minnesota
# 2    LH-16900   Lena Hernandez          Email        Dover    Delaware
# 3    TB-21055  Ted Butterfield          Email         Troy    New York
# 4    KM-16720     Kunst Miller          Email  Los Angeles  California
#
#    Postal Code   Region                 Category Sub-Category  \
# 0    90,049.00     West  Special Projects Muesil  Gluten Free
# 1    55,122.00  Central  Special Projects Muesil  Gluten Free
# 2    19,901.00     East  Special Projects Muesil  Gluten Free
# 3    12,180.00     East  Special Projects Muesil  Gluten Free
# 4    90,004.00     West  Special Projects Muesil  Gluten Free
#
#         Product ID  Sales  Quantity  Discount  Profit
# 0  TEC-AC-10003027  90.57         3      0.00   11.77
# 1  TEC-AC-10000171  45.98         2      0.00   19.77
# 2  TEC-AC-10002167  45.00         3      0.00    4.95
# 3  TEC-AC-10002167  30.00         2      0.00    3.30
# 4  TEC-AC-10004633  13.98         2      0.00    6.15

# %%
# check if process time is 2 days for standard processing formula = ready to ship - order date
check_process_time = pd.merge(df_hypo, 
                      df_ids, 
                      on ='Order ID', 
                      how ='inner')
check_process_time
# Out:
#      Unnamed: 0  Index        Order ID  Order Date            Ship Mode  \
# 0             8    107  CA-2020-119004  2020-11-23  Standard Processing
# 1             8    107  CA-2020-119004  2020-11-23  Standard Processing
# 2          3507    108  CA-2020-119004  2020-11-23  Standard Processing
# 3          3507    108  CA-2020-119004  2020-11-23  Standard Processing
# 4          7086    109  CA-2020-119004  2020-11-23  Standard Processing
# ..          ...    ...             ...         ...                  ...
# 748        9431    961  CA-2020-152142  2020-11-14  Standard Processing
# 749        9453   1314  US-2019-134488  2019-09-24  Standard Processing
# 750        9661   4753  CA-2020-103499  2020-11-20  Standard Processing
# 751        9948   9289  US-2020-165456  2020-11-30              Express
# 752        9963   9463  US-2020-109610  2020-11-25  Standard Processing
#
#     Customer ID     Customer Name Origin Channel           City  \
# 0      JM-15250      Janet Martin          Email      Charlotte
# 1      JM-15250      Janet Martin          Email      Charlotte
# 2      JM-15250      Janet Martin          Email      Charlotte
# 3      JM-15250      Janet Martin          Email      Charlotte
# 4      JM-15250      Janet Martin          Email      Charlotte
# ..          ...               ...            ...            ...
# 748    LW-16990  Lindsay Williams          Sales  San Francisco
# 749    PK-19075         Pete Kriz          Email       Columbus
# 750    ES-14020       Erica Smith          Email        Jackson
# 751    TB-21625       Trudy Brown          Email   Philadelphia
# 752    BS-11590     Brendan Sweed          Sales     Louisville
#
#               State  ...  Region                 Category        Sub-Category  \
# 0    North Carolina  ...   South  Special Projects Muesil         Gluten Free
# 1    North Carolina  ...   South  Special Projects Muesil         Gluten Free
# 2    North Carolina  ...   South  Special Projects Muesil           Only Oats
# 3    North Carolina  ...   South  Special Projects Muesil           Only Oats
# 4    North Carolina  ...   South             Power Muesli  Super Mega Protein
# ..              ...  ...     ...                      ...                 ...
# 748      California  ...    West           Toasted Muesli           With Nuts
# 749            Ohio  ...    East           Toasted Muesli           With Nuts
# 750       Tennessee  ...   South           Toasted Muesli           With Nuts
# 751    Pennsylvania  ...    East           Toasted Muesli           With Nuts
# 752        Kentucky  ...   South           Toasted Muesli           With Nuts
#
#           Product ID    Sales  Quantity  Discount  Profit  Ready to Ship Date  \
# 0    TEC-AC-10003499    74.11         8      0.20   17.60          2020-11-30
# 1    TEC-AC-10003499    74.11         8      0.20   17.60          2020-11-30
# 2    TEC-PH-10002844    27.99         1      0.20    2.10          2020-11-30
# 3    TEC-PH-10002844    27.99         1      0.20    2.10          2020-11-30
# 4    OFF-AR-10000390     3.30         1      0.20    1.07          2020-11-30
# ..               ...      ...       ...       ...     ...                 ...
# 748  FUR-CH-10002965   321.57         2      0.20   28.14          2020-11-16
# 749  FUR-CH-10003199   155.37         2      0.30  -13.32          2019-10-01
# 750  FUR-CH-10001482   209.57         2      0.20  -23.58          2020-11-24
# 751  FUR-CH-10003981 1,079.32         6      0.30  -15.42          2020-12-03
# 752  FUR-CH-10001854   701.96         2      0.00  168.47          2020-11-30
#
#     Pickup Date
# 0    2020-12-02
# 1    2020-12-02
# 2    2020-12-02
# 3    2020-12-02
# 4    2020-12-02
# ..          ...
# 748  2020-11-18
# 749  2019-10-02
# 750  2020-11-25
# 751  2020-12-04
# 752  2020-12-02
#
# [753 rows x 21 columns]

# %%
check_process_time[['Order ID', 'Order Date','Ready to Ship Date', 'Ship Mode']]
# Out:
#            Order ID  Order Date Ready to Ship Date            Ship Mode
# 0    CA-2020-119004  2020-11-23         2020-11-30  Standard Processing
# 1    CA-2020-119004  2020-11-23         2020-11-30  Standard Processing
# 2    CA-2020-119004  2020-11-23         2020-11-30  Standard Processing
# 3    CA-2020-119004  2020-11-23         2020-11-30  Standard Processing
# 4    CA-2020-119004  2020-11-23         2020-11-30  Standard Processing
# ..              ...         ...                ...                  ...
# 748  CA-2020-152142  2020-11-14         2020-11-16  Standard Processing
# 749  US-2019-134488  2019-09-24         2019-10-01  Standard Processing
# 750  CA-2020-103499  2020-11-20         2020-11-24  Standard Processing
# 751  US-2020-165456  2020-11-30         2020-12-03              Express
# 752  US-2020-109610  2020-11-25         2020-11-30  Standard Processing
#
# [753 rows x 4 columns]

# %%
check_process_time.columns = check_process_time.columns.str.lower()
check_process_time.columns = check_process_time.columns.str.replace(' ','_')
check_process_time
# Out:
#      unnamed:_0  index        order_id  order_date            ship_mode  \
# 0             8    107  CA-2020-119004  2020-11-23  Standard Processing
# 1             8    107  CA-2020-119004  2020-11-23  Standard Processing
# 2          3507    108  CA-2020-119004  2020-11-23  Standard Processing
# 3          3507    108  CA-2020-119004  2020-11-23  Standard Processing
# 4          7086    109  CA-2020-119004  2020-11-23  Standard Processing
# ..          ...    ...             ...         ...                  ...
# 748        9431    961  CA-2020-152142  2020-11-14  Standard Processing
# 749        9453   1314  US-2019-134488  2019-09-24  Standard Processing
# 750        9661   4753  CA-2020-103499  2020-11-20  Standard Processing
# 751        9948   9289  US-2020-165456  2020-11-30              Express
# 752        9963   9463  US-2020-109610  2020-11-25  Standard Processing
#
#     customer_id     customer_name origin_channel           city  \
# 0      JM-15250      Janet Martin          Email      Charlotte
# 1      JM-15250      Janet Martin          Email      Charlotte
# 2      JM-15250      Janet Martin          Email      Charlotte
# 3      JM-15250      Janet Martin          Email      Charlotte
# 4      JM-15250      Janet Martin          Email      Charlotte
# ..          ...               ...            ...            ...
# 748    LW-16990  Lindsay Williams          Sales  San Francisco
# 749    PK-19075         Pete Kriz          Email       Columbus
# 750    ES-14020       Erica Smith          Email        Jackson
# 751    TB-21625       Trudy Brown          Email   Philadelphia
# 752    BS-11590     Brendan Sweed          Sales     Louisville
#
#               state  ...  region                 category        sub-category  \
# 0    North Carolina  ...   South  Special Projects Muesil         Gluten Free
# 1    North Carolina  ...   South  Special Projects Muesil         Gluten Free
# 2    North Carolina  ...   South  Special Projects Muesil           Only Oats
# 3    North Carolina  ...   South  Special Projects Muesil           Only Oats
# 4    North Carolina  ...   South             Power Muesli  Super Mega Protein
# ..              ...  ...     ...                      ...                 ...
# 748      California  ...    West           Toasted Muesli           With Nuts
# 749            Ohio  ...    East           Toasted Muesli           With Nuts
# 750       Tennessee  ...   South           Toasted Muesli           With Nuts
# 751    Pennsylvania  ...    East           Toasted Muesli           With Nuts
# 752        Kentucky  ...   South           Toasted Muesli           With Nuts
#
#           product_id    sales  quantity  discount  profit  ready_to_ship_date  \
# 0    TEC-AC-10003499    74.11         8      0.20   17.60          2020-11-30
# 1    TEC-AC-10003499    74.11         8      0.20   17.60          2020-11-30
# 2    TEC-PH-10002844    27.99         1      0.20    2.10          2020-11-30
# 3    TEC-PH-10002844    27.99         1      0.20    2.10          2020-11-30
# 4    OFF-AR-10000390     3.30         1      0.20    1.07          2020-11-30
# ..               ...      ...       ...       ...     ...                 ...
# 748  FUR-CH-10002965   321.57         2      0.20   28.14          2020-11-16
# 749  FUR-CH-10003199   155.37         2      0.30  -13.32          2019-10-01
# 750  FUR-CH-10001482   209.57         2      0.20  -23.58          2020-11-24
# 751  FUR-CH-10003981 1,079.32         6      0.30  -15.42          2020-12-03
# 752  FUR-CH-10001854   701.96         2      0.00  168.47          2020-11-30
#
#     pickup_date
# 0    2020-12-02
# 1    2020-12-02
# 2    2020-12-02
# 3    2020-12-02
# 4    2020-12-02
# ..          ...
# 748  2020-11-18
# 749  2019-10-02
# 750  2020-11-25
# 751  2020-12-04
# 752  2020-12-02
#
# [753 rows x 21 columns]

# %%
check_process_time_standard = check_process_time.iloc[: , [1, 2,3,4,19,20]].copy()
check_process_time_standard["order_date"]=pd.to_datetime(check_process_time_standard["order_date"], format='%Y.%m.%d')
check_process_time_standard["order_date"]=pd.to_datetime(check_process_time_standard["order_date"].dt.date)
check_process_time_standard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 753 entries, 0 to 752
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               753 non-null    int64
#  1   order_id            753 non-null    object
#  2   order_date          753 non-null    datetime64[ns]
#  3   ship_mode           753 non-null    object
#  4   ready_to_ship_date  753 non-null    datetime64[ns]
#  5   pickup_date         753 non-null    datetime64[ns]
# dtypes: datetime64[ns](3), int64(1), object(2)
# memory usage: 41.2+ KB

# %%
#check_process_time_standard.query('ready_to_ship_date - order_date').dt.days
#check_process_time_standard['process_time']=(check_process_time["ready_to_ship_date"]-check_process_time["order_date"]).dt.days
#check_process_time_standard['trending_days_difference']=(check_process_time_standard["trending_date"]-check_process_time_standard["publish_date"]).dt.days
#check_process_time_standard['process_time']=(check_process_time_standard["ready_to_ship_date"]-check_process_time_standard["order_date"]).dt.days
check_process_time_standard
# Out:
#      index        order_id order_date            ship_mode ready_to_ship_date  \
# 0      107  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 1      107  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 2      108  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 3      108  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 4      109  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# ..     ...             ...        ...                  ...                ...
# 748    961  CA-2020-152142 2020-11-14  Standard Processing         2020-11-16
# 749   1314  US-2019-134488 2019-09-24  Standard Processing         2019-10-01
# 750   4753  CA-2020-103499 2020-11-20  Standard Processing         2020-11-24
# 751   9289  US-2020-165456 2020-11-30              Express         2020-12-03
# 752   9463  US-2020-109610 2020-11-25  Standard Processing         2020-11-30
#
#      process_time
# 0               7
# 1               7
# 2               7
# 3               7
# 4               7
# ..            ...
# 748             2
# 749             7
# 750             4
# 751             3
# 752             5
#
# [753 rows x 6 columns]

# %%
#check_process_time_standard.describe()
#check_process_time_standard.query('ship_mode' == 'Standard Processing')
check_process_time_standard.loc[check_process_time_standard['ship_mode'] == 'Standard Processing'].describe()
# Out:
#          index  process_time
# count   602.00        602.00
# mean  5,525.51          4.88
# std   2,776.21          1.26
# min      97.00          2.00
# 25%   3,139.00          4.00
# 50%   5,506.00          5.00
# 75%   8,170.00          6.00
# max   9,973.00          8.00

# %% [markdown]
# mean process time for standard processing is almost 5 days and the median is exactly 5 days. Müsli Comapanies assumption of 2 days processing time has to be rejected in this sample

# %%
check_process_time_standard.loc[check_process_time_standard['ship_mode'] == 'Express'].describe()
# Out:
#          index  process_time
# count   151.00        151.00
# mean  4,598.68          2.08
# std   3,082.02          1.82
# min     511.00          0.00
# 25%   1,654.00          0.00
# 50%   4,012.00          2.00
# 75%   7,293.50          3.00
# max   9,930.00          5.00

# %% [markdown]
# mean process time for standard processing is almost 2 days and the median is exactly 2 days. Müsli Comapanies assumption of 2 days processing time for express processing is correct in this sample

# %%
check_process_time_standard['pick_up']=(check_process_time_standard["pickup_date"]-check_process_time_standard["order_date"]).dt.days
check_process_time_standard.describe()
# Out:
#      index        order_id order_date            ship_mode ready_to_ship_date  \
# 0      107  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 1      107  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 2      108  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 3      108  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# 4      109  CA-2020-119004 2020-11-23  Standard Processing         2020-11-30
# ..     ...             ...        ...                  ...                ...
# 748    961  CA-2020-152142 2020-11-14  Standard Processing         2020-11-16
# 749   1314  US-2019-134488 2019-09-24  Standard Processing         2019-10-01
# 750   4753  CA-2020-103499 2020-11-20  Standard Processing         2020-11-24
# 751   9289  US-2020-165456 2020-11-30              Express         2020-12-03
# 752   9463  US-2020-109610 2020-11-25  Standard Processing         2020-11-30
#
#     pickup_date  pick_up
# 0    2020-12-02        9
# 1    2020-12-02        9
# 2    2020-12-02        9
# 3    2020-12-02        9
# 4    2020-12-02        9
# ..          ...      ...
# 748  2020-11-18        4
# 749  2019-10-02        8
# 750  2020-11-25        5
# 751  2020-12-04        4
# 752  2020-12-02        7
#
# [753 rows x 7 columns]

# %%
check_process_time_standard.describe()
# Out:
#          index  pick_up
# count   753.00   753.00
# mean  5,339.65     6.07
# std   2,862.22     2.36
# min      97.00     0.00
# 25%   2,973.00     5.00
# 50%   5,333.00     7.00
# 75%   8,046.00     8.00
# max   9,973.00    10.00

# %%
check_process_time_standard.loc[check_process_time_standard['ship_mode'] == 'Standard Processing'].describe()
# Out:
#          index  pick_up
# count   602.00   602.00
# mean  5,525.51     6.98
# std   2,776.21     1.45
# min      97.00     3.00
# 25%   3,139.00     6.00
# 50%   5,506.00     7.00
# 75%   8,170.00     8.00
# max   9,973.00    10.00

# %%
check_process_time_standard.loc[check_process_time_standard['ship_mode'] == 'Express'].describe()
# Out:
#          index  pick_up
# count   151.00   151.00
# mean  4,598.68     2.46
# std   3,082.02     1.75
# min     511.00     0.00
# 25%   1,654.00     1.00
# 50%   4,012.00     2.00
# 75%   7,293.50     4.00
# max   9,930.00     6.00

# %%
df_cd.columns = df_cd.columns.str.lower()
df_cd.columns = df_cd.columns.str.replace(' ','_')
df_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   order_id           333 non-null    object
#  1   arrival_scan_date  333 non-null    datetime64[ns]
#  2   customer_name      333 non-null    object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 7.9+ KB

# %%
check_process_time = pd.merge(check_process_time, 
                      df_cd, 
                      on ='order_id', 
                      how ='inner')
check_process_time
# Out:
#     unnamed:_0  index        order_id  order_date            ship_mode  \
# 0           17    252  CA-2019-145625  2019-09-11  Standard Processing
# 1           17    252  CA-2019-145625  2019-09-11  Standard Processing
# 2         2157    251  CA-2019-145625  2019-09-11  Standard Processing
# 3         2157    251  CA-2019-145625  2019-09-11  Standard Processing
# 4           85   1042  CA-2019-102981  2019-09-06  Standard Processing
# ..         ...    ...             ...         ...                  ...
# 79        5697    992  CA-2019-110023  2019-09-09              Express
# 80        6389   5399  CA-2019-163202  2019-09-27  Standard Processing
# 81        6835   8468  CA-2019-168557  2019-09-19  Standard Processing
# 82        8403   9281  CA-2019-166772  2019-09-20  Standard Processing
# 83        9074   6937  CA-2019-129847  2019-09-02              Express
#
#    customer_id  customer_name_x origin_channel           city       state  \
# 0     KC-16540  Kelly Collister          Email      San Diego  California
# 1     KC-16540  Kelly Collister          Email      San Diego  California
# 2     KC-16540  Kelly Collister          Email      San Diego  California
# 3     KC-16540  Kelly Collister          Email      San Diego  California
# 4     MO-17500    Mary O'Rourke          Email  New York City    New York
# ..         ...              ...            ...            ...         ...
# 79    TS-21610     Troy Staebel          Email  New York City    New York
# 80    BM-11650       Brian Moss          Sales      Lancaster        Ohio
# 81    FH-14275     Frank Hawley          Sales  San Francisco  California
# 82    HJ-14875      Heather Jas       Facebook        Seattle  Washington
# 83    TA-21385     Tom Ashbrook       Facebook        Chicago    Illinois
#
#     ...         sub-category       product_id    sales quantity discount  \
# 0   ...          Gluten Free  TEC-AC-10003832 3,347.37       13     0.00
# 1   ...          Gluten Free  TEC-AC-10003832 3,347.37       13     0.00
# 2   ...        Nuts and more  OFF-PA-10004569     7.61        1     0.00
# 3   ...        Nuts and more  OFF-PA-10004569     7.61        1     0.00
# 4   ...          Gluten Free  TEC-AC-10004761    31.86        2     0.00
# ..  ...                  ...              ...      ...      ...      ...
# 79  ...    Super Fibre Boost  OFF-BI-10001036    14.62        2     0.20
# 80  ...    Super Fibre Boost  OFF-BI-10002764     2.91        3     0.70
# 81  ...    Super Fibre Boost  OFF-BI-10002309     8.93        2     0.20
# 82  ...           With Fruit  FUR-BO-10002853   163.88        2     0.00
# 83  ...  With Fruit and Nuts  FUR-FU-10000277    84.27        2     0.60
#
#     profit  ready_to_ship_date  pickup_date  arrival_scan_date  \
# 0   636.00          2019-09-17   2019-09-18         2019-09-23
# 1   636.00          2019-09-17   2019-09-18         2019-09-23
# 2     3.58          2019-09-17   2019-09-18         2019-09-23
# 3     3.58          2019-09-17   2019-09-18         2019-09-23
# 4    11.15          2019-09-09   2019-09-11         2019-09-16
# ..     ...                 ...          ...                ...
# 79    5.48          2019-09-11   2019-09-11         2019-09-16
# 80   -2.03          2019-10-02   2019-10-04         2019-10-07
# 81    3.12          2019-09-23   2019-09-25         2019-09-30
# 82   40.97          2019-09-24   2019-09-25         2019-09-30
# 83  -75.84          2019-09-04   2019-09-04         2019-09-10
#
#     customer_name_y
# 0   Kelly Collister
# 1   Kelly Collister
# 2   Kelly Collister
# 3   Kelly Collister
# 4     Mary O'Rourke
# ..              ...
# 79     Troy Staebel
# 80       Brian Moss
# 81     Frank Hawley
# 82      Heather Jas
# 83     Tom Ashbrook
#
# [84 rows x 23 columns]

# %%
check_process_time_standard = check_process_time.iloc[: , [1, 2,3,4,19,20,21]].copy()
check_process_time_standard["order_date"]=pd.to_datetime(check_process_time_standard["order_date"], format='%Y.%m.%d')
check_process_time_standard["order_date"]=pd.to_datetime(check_process_time_standard["order_date"].dt.date)
check_process_time_standard.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 0 to 83
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               84 non-null     int64
#  1   order_id            84 non-null     object
#  2   order_date          84 non-null     datetime64[ns]
#  3   ship_mode           84 non-null     object
#  4   ready_to_ship_date  84 non-null     datetime64[ns]
#  5   pickup_date         84 non-null     datetime64[ns]
#  6   arrival_scan_date   84 non-null     datetime64[ns]
# dtypes: datetime64[ns](4), int64(1), object(2)
# memory usage: 5.2+ KB

# %%
check_process_time_standard['arrival']=(check_process_time_standard["arrival_scan_date"]-check_process_time_standard["order_date"]).dt.days

check_process_time_standard
# Out:
#     index        order_id order_date            ship_mode ready_to_ship_date  \
# 0     252  CA-2019-145625 2019-09-11  Standard Processing         2019-09-17
# 1     252  CA-2019-145625 2019-09-11  Standard Processing         2019-09-17
# 2     251  CA-2019-145625 2019-09-11  Standard Processing         2019-09-17
# 3     251  CA-2019-145625 2019-09-11  Standard Processing         2019-09-17
# 4    1042  CA-2019-102981 2019-09-06  Standard Processing         2019-09-09
# ..    ...             ...        ...                  ...                ...
# 79    992  CA-2019-110023 2019-09-09              Express         2019-09-11
# 80   5399  CA-2019-163202 2019-09-27  Standard Processing         2019-10-02
# 81   8468  CA-2019-168557 2019-09-19  Standard Processing         2019-09-23
# 82   9281  CA-2019-166772 2019-09-20  Standard Processing         2019-09-24
# 83   6937  CA-2019-129847 2019-09-02              Express         2019-09-04
#
#    pickup_date arrival_scan_date  arrival
# 0   2019-09-18        2019-09-23       12
# 1   2019-09-18        2019-09-23       12
# 2   2019-09-18        2019-09-23       12
# 3   2019-09-18        2019-09-23       12
# 4   2019-09-11        2019-09-16       10
# ..         ...               ...      ...
# 79  2019-09-11        2019-09-16        7
# 80  2019-10-04        2019-10-07       10
# 81  2019-09-25        2019-09-30       11
# 82  2019-09-25        2019-09-30       10
# 83  2019-09-04        2019-09-10        8
#
# [84 rows x 8 columns]

# %%
check_process_time_standard.loc[check_process_time_standard['ship_mode'] == 'Standard Processing'].describe()
# Out:
#          index  arrival
# count    76.00    76.00
# mean  3,889.18    10.76
# std   2,393.04     1.47
# min      99.00     8.00
# 25%   2,638.25    10.00
# 50%   3,413.00    10.00
# 75%   5,333.00    12.00
# max   9,973.00    13.00

# %% [markdown]
# mean time between order and arrival for standard processing is almost 11 days and the median is exactly 10 days. Müsli Comapanies assumption of about 7 days between order and arrival is not correct for the sample (76)

# %%
check_process_time_standard.loc[check_process_time_standard['ship_mode'] == 'Express'].describe()
# Out:
#          index  arrival
# count     8.00     8.00
# mean  3,908.75     7.12
# std   4,261.13     1.36
# min     870.00     5.00
# 25%     870.75     6.50
# 50%     931.50     8.00
# 75%   7,685.00     8.00
# max   9,930.00     8.00

# %% [markdown]
# mean time between order and arrival for express is about 7 days and the median is exactly 8 days. Müsli Comapanies assumption of about 7 days between order and arrival is almost correct for the sample (8)

# %%
df_opd.columns = df_opd.columns.str.lower()
df_opd.columns = df_opd.columns.str.replace(' ','_')
df_opd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5899 entries, 0 to 5898
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   row_id              5899 non-null   int64
#  1   order_id            5899 non-null   object
#  2   order_date          5899 non-null   datetime64[ns]
#  3   on_truck_scan_date  5899 non-null   datetime64[ns]
#  4   ship_mode           5899 non-null   object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 230.6+ KB

# %%
check_process_time = pd.merge(check_process_time, 
                      df_opd, 
                      on ='order_id', 
                      how ='inner')
check_process_time
# Out:
#      unnamed:_0  index        order_id order_date_x          ship_mode_x  \
# 0            17    252  CA-2019-145625   2019-09-11  Standard Processing
# 1            17    252  CA-2019-145625   2019-09-11  Standard Processing
# 2            17    252  CA-2019-145625   2019-09-11  Standard Processing
# 3            17    252  CA-2019-145625   2019-09-11  Standard Processing
# 4          2157    251  CA-2019-145625   2019-09-11  Standard Processing
# ..          ...    ...             ...          ...                  ...
# 245        5697    992  CA-2019-110023   2019-09-09              Express
# 246        6389   5399  CA-2019-163202   2019-09-27  Standard Processing
# 247        6835   8468  CA-2019-168557   2019-09-19  Standard Processing
# 248        8403   9281  CA-2019-166772   2019-09-20  Standard Processing
# 249        9074   6937  CA-2019-129847   2019-09-02              Express
#
#     customer_id  customer_name_x origin_channel           city       state  \
# 0      KC-16540  Kelly Collister          Email      San Diego  California
# 1      KC-16540  Kelly Collister          Email      San Diego  California
# 2      KC-16540  Kelly Collister          Email      San Diego  California
# 3      KC-16540  Kelly Collister          Email      San Diego  California
# 4      KC-16540  Kelly Collister          Email      San Diego  California
# ..          ...              ...            ...            ...         ...
# 245    TS-21610     Troy Staebel          Email  New York City    New York
# 246    BM-11650       Brian Moss          Sales      Lancaster        Ohio
# 247    FH-14275     Frank Hawley          Sales  San Francisco  California
# 248    HJ-14875      Heather Jas       Facebook        Seattle  Washington
# 249    TA-21385     Tom Ashbrook       Facebook        Chicago    Illinois
#
#      ...  discount profit ready_to_ship_date pickup_date arrival_scan_date  \
# 0    ...      0.00 636.00         2019-09-17  2019-09-18        2019-09-23
# 1    ...      0.00 636.00         2019-09-17  2019-09-18        2019-09-23
# 2    ...      0.00 636.00         2019-09-17  2019-09-18        2019-09-23
# 3    ...      0.00 636.00         2019-09-17  2019-09-18        2019-09-23
# 4    ...      0.00   3.58         2019-09-17  2019-09-18        2019-09-23
# ..   ...       ...    ...                ...         ...               ...
# 245  ...      0.20   5.48         2019-09-11  2019-09-11        2019-09-16
# 246  ...      0.70  -2.03         2019-10-02  2019-10-04        2019-10-07
# 247  ...      0.20   3.12         2019-09-23  2019-09-25        2019-09-30
# 248  ...      0.00  40.97         2019-09-24  2019-09-25        2019-09-30
# 249  ...      0.60 -75.84         2019-09-04  2019-09-04        2019-09-10
#
#      customer_name_y  row_id  order_date_y  on_truck_scan_date  \
# 0    Kelly Collister     251    2019-09-11          2019-09-18
# 1    Kelly Collister     252    2019-09-11          2019-09-18
# 2    Kelly Collister     251    2019-09-11          2019-09-18
# 3    Kelly Collister     252    2019-09-11          2019-09-18
# 4    Kelly Collister     251    2019-09-11          2019-09-18
# ..               ...     ...           ...                 ...
# 245     Troy Staebel     992    2019-09-09          2019-09-11
# 246       Brian Moss    5399    2019-09-27          2019-10-04
# 247     Frank Hawley    8468    2019-09-19          2019-09-25
# 248      Heather Jas    9281    2019-09-20          2019-09-25
# 249     Tom Ashbrook    6937    2019-09-02          2019-09-04
#
#              ship_mode_y
# 0    Standard Processing
# 1    Standard Processing
# 2    Standard Processing
# 3    Standard Processing
# 4    Standard Processing
# ..                   ...
# 245              Express
# 246  Standard Processing
# 247  Standard Processing
# 248  Standard Processing
# 249              Express
#
# [250 rows x 27 columns]

# %%
# letzer stand scan on truck zu arrival

# %%
check_process_time= check_process_time.iloc[: , [1, 2,3,4,19,20,21,22]].copy()
check_process_time["order_date"]=pd.to_datetime(check_process_time["order_date"], format='%Y.%m.%d')
check_process_time["order_date"]=pd.to_datetime(check_process_time["order_date"].dt.date)
check_process_time
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'order_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb Cell 58' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000057?line=0'>1</a> check_process_time= check_process_time.iloc[: , [1, 2,3,4,19,20,21,22]].copy()
# ----> <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000057?line=1'>2</a> check_process_time["order_date"]=pd.to_datetime(check_process_time["order_date"], format='%Y.%m.%d')
#       <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000057?line=2'>3</a> check_process_time["order_date"]=pd.to_datetime(check_process_time["order_date"].dt.date)
#       <a href='vscode-notebook-cell:/Users/christian/neuefische/da-EDA_Project_Ulla-Christian/data_cleaning_1.ipynb#ch0000057?line=3'>4</a> check_process_time
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/frame.py?line=3502'>3503</a> if self.columns.nlevels > 1:
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/frame.py?line=3503'>3504</a>     return self._getitem_multilevel(key)
# -> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/frame.py?line=3504'>3505</a> indexer = self.columns.get_loc(key)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/frame.py?line=3505'>3506</a> if is_integer(indexer):
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/frame.py?line=3506'>3507</a>     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
# -> <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3622'>3623</a>     raise KeyError(key) from err
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3623'>3624</a> except TypeError:
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3624'>3625</a>     # If we have a listlike key, _check_indexing_error will raise
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3625'>3626</a>     #  InvalidIndexError. Otherwise we fall through and re-raise
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3626'>3627</a>     #  the TypeError.
#    <a href='file:///opt/homebrew/Caskroom/miniconda/base/envs/nf_geo/lib/python3.9/site-packages/pandas/core/indexes/base.py?line=3627'>3628</a>     self._check_indexing_error(key)
#
# KeyError: 'order_date'
